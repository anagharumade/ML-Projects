# %% [markdown]
# ## Objective of this Notebook
# <br>
# Trying to find Better Initial Centroids for K-Means Clustering so that the number of iterations required to converge on the final Centroids are lesser hence the process is faster

# %% [markdown]
# ### Reading the Data
# Information about the Dataset: https://archive.ics.uci.edu/ml/datasets/3D+Road+Network+(North+Jutland,+Denmark)

# %%
import pandas as pd

# %%
data = pd.read_csv('3D_spatial_network.csv', header=None)

# %%
data.columns = ['OSM_ID', 'LONGITUDE', 'LATTITUDE', 'ALTITUDE']

# %%
data.head()
# Out:
#       OSM_ID  LONGITUDE  LATTITUDE   ALTITUDE
# 0  144552912   9.349849  56.740876  17.052772
# 1  144552912   9.350188  56.740679  17.614840
# 2  144552912   9.350549  56.740544  18.083536
# 3  144552912   9.350806  56.740484  18.279465
# 4  144552912   9.351053  56.740486  18.422974

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import libraryEDA as lib

# %%
lib.EDA(data)
# Out:
# Number of Rows in the DataFrame: 434874
#
# Number of Columns in the DataFrame: 4
#
# Descriptive Statistics of the DataFrame are as follows:
#                   0              1              2              3
# count  4.348740e+05  434874.000000  434874.000000  434874.000000
# mean   9.786998e+07       9.731836      57.083758      22.185405
# std    3.775233e+07       0.627349       0.289479      18.617989
# min    4.482444e+06       8.146126      56.582486      -8.608184
# 25%    8.267897e+07       9.337649      56.846049       7.028053
# 50%    1.019797e+08       9.887195      57.042498      17.574678
# 75%    1.259547e+08      10.172359      57.308669      31.810224
# max    1.577424e+08      11.199326      57.750511     134.441947
#
# Columns with Missing Values
# Empty DataFrame
# Columns: [Column Name, # Missing Values]
# Index: []
#
# DataTypes of all columns
# 0      int64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %% [markdown]
# No missing values

# %% [markdown]
# ### Data Preperation
#
# There are no missing values or classes in the data.<br>
# We normalize the data and drop the column OSM_ID as that is not useful for our clustering

# %%
data.drop(labels='OSM_ID', axis=1, inplace=True)

# %%
from sklearn import preprocessing

# %%
sc = preprocessing.MinMaxScaler()

# %%
data_sc = sc.fit_transform(data.values)

# %%
data = pd.DataFrame(data_sc)

# %%
data.head()
# Out:
#           0         1         2
# 0  0.394249  0.135605  0.179384
# 1  0.394361  0.135436  0.183314
# 2  0.394479  0.135321  0.186590
# 3  0.394563  0.135270  0.187960
# 4  0.394644  0.135272  0.188963

# %% [markdown]
# ### Process of finding better initial centroids for K-Means Clustering
#
# Step 1: Pick samples from the dataset<br>
# Step 2: Run K-Means algorithm iterations n number of times on it<br>

# %%
SAMPLE_SIZE = 0.1
RANDOM_STATE = 42
NUM_CLUSTERS = 10     # k
NUM_ITER = 3          # n
NUM_ATTEMPTS = 5      # m

data_sample = data.sample(frac=SAMPLE_SIZE, random_state=RANDOM_STATE, replace=False)
data_sample.shape
# Out:
# (43487, 3)

# %%
from sklearn.cluster import KMeans

km = KMeans(n_clusters=NUM_CLUSTERS, init='random', max_iter=1, n_init=1)#, verbose=1)
km.fit(data_sample)

print('Pre-clustering metrics')
print('----------------------')
print('Inertia:', km.inertia_)
print('Centroids:', km.cluster_centers_)
# Out:
# Pre-clustering metrics
# ----------------------
# Inertia: 1012.60352115
# Centroids: [[ 0.33255532  0.38687508  0.13979188]
#  [ 0.17580137  0.07500607  0.2294287 ]
#  [ 0.15458061  0.25273311  0.18798365]
#  [ 0.64840057  0.55808029  0.13148556]
#  [ 0.45406389  0.08958653  0.26582884]
#  [ 0.5699669   0.3745683   0.13456748]
#  [ 0.69634176  0.29119515  0.09901808]
#  [ 0.56485591  0.26679838  0.39509002]
#  [ 0.67075957  0.81857143  0.24085752]
#  [ 0.68648569  0.66983186  0.24874021]]

# %%
final_cents = []
final_inert = []
    
for sample in range(NUM_ATTEMPTS):
    print('\nCentroid attempt: ', sample)
    km = KMeans(n_clusters=NUM_CLUSTERS, init='random', max_iter=1, n_init=1)#, verbose=1) 
    km.fit(data_sample)
    inertia_start = km.inertia_
    intertia_end = 0
    cents = km.cluster_centers_
        
    for iter in range(NUM_ITER):
        km = KMeans(n_clusters=NUM_CLUSTERS, init=cents, max_iter=1, n_init=1)
        km.fit(data_sample)
        print('Iteration: ', iter)
        print('Inertia:', km.inertia_)
        print('Centroids:', km.cluster_centers_)
        inertia_end = km.inertia_
        cents = km.cluster_centers_

    final_cents.append(cents)
    final_inert.append(inertia_end)
    print('Difference between initial and final inertia: ', inertia_start-inertia_end)
# Out:
# Centroid attempt:  0
# Iteration:  0
# Inertia: 909.41638077
# Centroids: [[ 0.55059892  0.10729486  0.36109086]
#  [ 0.42275889  0.13662652  0.20143432]
#  [ 0.57508514  0.33846074  0.2971163 ]
#  [ 0.44444158  0.5318972   0.15649561]
#  [ 0.55280816  0.41767155  0.10815682]
#  [ 0.77293781  0.79176057  0.11370021]
#  [ 0.16934451  0.23806167  0.18633921]
#  [ 0.57031069  0.26379549  0.55919627]
#  [ 0.66138394  0.69542807  0.31733501]
#  [ 0.65663419  0.33947277  0.12062702]]
# Iteration:  1
# Inertia: 889.993859664
# Centroids: [[ 0.56011985  0.10553658  0.3448233 ]
#  [ 0.38584656  0.13921513  0.20812626]
#  [ 0.56327522  0.34194838  0.30298824]
#  [ 0.44345146  0.53279726  0.15341629]
#  [ 0.55582455  0.41437762  0.11358421]
#  [ 0.76896359  0.78348386  0.11817672]
#  [ 0.16172169  0.24507193  0.18338347]
#  [ 0.5716509   0.2700144   0.55639128]
#  [ 0.65512919  0.6952581   0.33003951]
#  [ 0.66617805  0.32363351  0.12027365]]
# Iteration:  2
# Inertia: 876.444163865
# Centroids: [[ 0.56241546  0.10312694  0.33331749]
#  [ 0.36449926  0.13969479  0.20828676]
#  [ 0.5556044   0.34569383  0.30789907]
#  [ 0.44480138  0.53390274  0.15071068]
#  [ 0.56772864  0.41417126  0.12047615]
#  [ 0.76708383  0.78093541  0.12013418]
#  [ 0.15591382  0.2527181   0.18250061]
#  [ 0.57045506  0.26286732  0.55281592]
#  [ 0.65436993  0.6950631   0.33535523]
#  [ 0.67155083  0.29638845  0.11252028]]
# Difference between initial and final inertia:  92.2199141341
#
# Centroid attempt:  1
# Iteration:  0
# Inertia: 899.98925757
# Centroids: [[ 0.27631058  0.08306987  0.31255475]
#  [ 0.58285678  0.1503454   0.34320521]
#  [ 0.68340795  0.65007726  0.48879068]
#  [ 0.27594037  0.3851631   0.1510625 ]
#  [ 0.48941767  0.55694359  0.16449951]
#  [ 0.71716473  0.76200082  0.17260837]
#  [ 0.61040745  0.39507146  0.1585805 ]
#  [ 0.10551952  0.2122602   0.18325103]
#  [ 0.41303934  0.18411599  0.24716051]
#  [ 0.26279957  0.15627108  0.13331098]]
# Iteration:  1
# Inertia: 883.607827491
# Centroids: [[ 0.25744348  0.08694279  0.30318629]
#  [ 0.58124733  0.15948773  0.35779832]
#  [ 0.68110213  0.65360806  0.46865229]
#  [ 0.27063715  0.39209764  0.15426151]
#  [ 0.50534858  0.56597338  0.16599313]
#  [ 0.72327899  0.76754681  0.16513203]
#  [ 0.61099788  0.38714474  0.15248029]
#  [ 0.10776737  0.22413838  0.19109225]
#  [ 0.42799641  0.17430616  0.23873545]
#  [ 0.26471789  0.14446084  0.12691066]]
# Iteration:  2
# Inertia: 871.246443402
# Centroids: [[ 0.23867275  0.09290232  0.29755624]
#  [ 0.57613819  0.16801781  0.37714603]
#  [ 0.68045596  0.65548369  0.4581411 ]
#  [ 0.2750434   0.39540308  0.15424408]
#  [ 0.51388455  0.57042661  0.16779373]
#  [ 0.72630351  0.77025118  0.16108645]
#  [ 0.61187835  0.37879068  0.14739282]
#  [ 0.10968981  0.23393846  0.19278895]
#  [ 0.43845147  0.16227707  0.23216506]
#  [ 0.26282238  0.1433795   0.12333201]]
# Difference between initial and final inertia:  88.7131043581
#
# Centroid attempt:  2
# Iteration:  0
# Inertia: 989.372524869
# Centroids: [[ 0.29955286  0.37701653  0.15326011]
#  [ 0.13588009  0.27812713  0.16896409]
#  [ 0.46132599  0.40047679  0.35693387]
#  [ 0.25041607  0.13124219  0.28992747]
#  [ 0.2600714   0.096569    0.13484303]
#  [ 0.6057556   0.36180216  0.12085468]
#  [ 0.77777351  0.57575826  0.21210403]
#  [ 0.52035363  0.5851306   0.15151909]
#  [ 0.55742675  0.17884366  0.34386324]
#  [ 0.69155407  0.78627728  0.24090283]]
# Iteration:  1
# Inertia: 926.250635776
# Centroids: [[ 0.31641332  0.38421034  0.13532982]
#  [ 0.12941815  0.28141883  0.1943337 ]
#  [ 0.54524294  0.41525889  0.39714061]
#  [ 0.26240988  0.12250138  0.29167558]
#  [ 0.26408886  0.10822154  0.13311254]
#  [ 0.60550002  0.35865431  0.12522109]
#  [ 0.78566673  0.58078114  0.19411694]
#  [ 0.52554635  0.58278746  0.15540002]
#  [ 0.54926581  0.1428905   0.34819095]
#  [ 0.69038838  0.79059914  0.23105147]]
# Iteration:  2
# Inertia: 892.840913174
# Centroids: [[ 0.33044933  0.38791152  0.13616639]
#  [ 0.13023439  0.28899883  0.20392943]
#  [ 0.58739614  0.44397429  0.42693916]
#  [ 0.27099177  0.11920797  0.28953351]
#  [ 0.25674524  0.11792945  0.12980249]
#  [ 0.60561056  0.35563065  0.12638126]
#  [ 0.80190331  0.58783306  0.16320991]
#  [ 0.52950665  0.58269635  0.15756673]
#  [ 0.54634818  0.13532265  0.34614634]
#  [ 0.68949395  0.79332682  0.22569317]]
# Difference between initial and final inertia:  178.86009616
#
# Centroid attempt:  3
# Iteration:  0
# Inertia: 953.242055416
# Centroids: [[ 0.59097678  0.47233236  0.13424165]
#  [ 0.47480883  0.35857214  0.2042025 ]
#  [ 0.52495001  0.11994385  0.28705505]
#  [ 0.75123561  0.89766717  0.11120916]
#  [ 0.75879103  0.69958877  0.18941015]
#  [ 0.65307184  0.51624288  0.54705115]
#  [ 0.17485369  0.22935737  0.18817178]
#  [ 0.58988053  0.7894123   0.16489863]
#  [ 0.63422805  0.72704251  0.31564639]
#  [ 0.87200173  0.6383394   0.08824287]]
# Iteration:  1
# Inertia: 922.425771759
# Centroids: [[ 0.5905661   0.45509796  0.1294476 ]
#  [ 0.46164906  0.3653087   0.20155422]
#  [ 0.53502038  0.13014923  0.30378195]
#  [ 0.74924141  0.89330723  0.11164165]
#  [ 0.76186625  0.69922416  0.16467232]
#  [ 0.65923088  0.54070076  0.54132207]
#  [ 0.18270217  0.22585601  0.18580693]
#  [ 0.57996094  0.76786874  0.18179937]
#  [ 0.64497238  0.71043467  0.33011253]
#  [ 0.91011592  0.59857994  0.08908074]]
# Iteration:  2
# Inertia: 907.363007567
# Centroids: [[ 0.59249313  0.44399088  0.12963518]
#  [ 0.44561839  0.37167554  0.1999757 ]
#  [ 0.54053728  0.13704085  0.31067661]
#  [ 0.74676212  0.89628582  0.11345609]
#  [ 0.76313489  0.70069054  0.15146562]
#  [ 0.66861086  0.56890896  0.54499384]
#  [ 0.18535526  0.22218576  0.18640784]
#  [ 0.57692603  0.75268639  0.19264263]
#  [ 0.65633468  0.69876474  0.33947342]
#  [ 0.92541961  0.59441083  0.08841302]]
# Difference between initial and final inertia:  105.372724209
#
# Centroid attempt:  4
# Iteration:  0
# Inertia: 1091.5930161
# Centroids: [[ 0.14934535  0.14536559  0.11203291]
#  [ 0.64751997  0.4407184   0.09570149]
#  [ 0.5736132   0.25814678  0.50925634]
#  [ 0.63034201  0.11813879  0.21115621]
#  [ 0.67213804  0.73859376  0.21906535]
#  [ 0.20048167  0.35725105  0.17432584]
#  [ 0.50261007  0.37358039  0.23608471]
#  [ 0.6265368   0.45076139  0.20909504]
#  [ 0.40975131  0.1530181   0.23081272]
#  [ 0.2158169   0.10922108  0.26568727]]
# Iteration:  1
# Inertia: 1028.79009227
# Centroids: [[ 0.14124535  0.15688162  0.12440705]
#  [ 0.63016189  0.43385782  0.09771351]
#  [ 0.57376163  0.26184476  0.4985384 ]
#  [ 0.63294185  0.12508089  0.20901174]
#  [ 0.69315227  0.75603615  0.21986027]
#  [ 0.20723118  0.36676739  0.17130138]
#  [ 0.48865477  0.37542949  0.22204381]
#  [ 0.59954295  0.51118302  0.21473133]
#  [ 0.41194814  0.14293824  0.23344004]
#  [ 0.21409151  0.11876918  0.27627471]]
# Iteration:  2
# Inertia: 994.218250046
# Centroids: [[ 0.1400045   0.16254062  0.12951909]
#  [ 0.62482539  0.40793622  0.10410223]
#  [ 0.57339594  0.26564473  0.48938797]
#  [ 0.63501468  0.12820102  0.20721046]
#  [ 0.70890865  0.76403634  0.2161081 ]
#  [ 0.20794968  0.37080268  0.17101985]
#  [ 0.48807248  0.37366621  0.21587564]
#  [ 0.58336576  0.5664678   0.20532776]
#  [ 0.41373023  0.13574057  0.23520832]
#  [ 0.21391811  0.12309273  0.28121391]]
# Difference between initial and final inertia:  165.73018986

# %% [markdown]
# Inertia : Sum of squares of distance from centroid to each point. <br>
# When the centroids are almost converging the difference in the initial and final inertia is less. <br><br>
# Step 3: we consider the centroids of the last iteration of the least difference in Inertia as the best centroids for our clustering algorithm

# %%
# Get best centroids to use for full clustering
best_cents = final_cents[final_inert.index(min(final_inert))]
best_cents
# Out:
# array([[ 0.23867275,  0.09290232,  0.29755624],
#        [ 0.57613819,  0.16801781,  0.37714603],
#        [ 0.68045596,  0.65548369,  0.4581411 ],
#        [ 0.2750434 ,  0.39540308,  0.15424408],
#        [ 0.51388455,  0.57042661,  0.16779373],
#        [ 0.72630351,  0.77025118,  0.16108645],
#        [ 0.61187835,  0.37879068,  0.14739282],
#        [ 0.10968981,  0.23393846,  0.19278895],
#        [ 0.43845147,  0.16227707,  0.23216506],
#        [ 0.26282238,  0.1433795 ,  0.12333201]])

# %% [markdown]
# Running the K-Means algorithm with the best centroids found as the initial Centroids

# %%
km_full = KMeans(n_clusters=NUM_CLUSTERS, init=best_cents, max_iter=100, verbose=1, n_init=1)
km_full.fit(data)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 8615.69337846
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 8447.30703369
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 8289.22072713
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 8159.99407089
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 8069.93498105
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 8004.91522631
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 7949.82292208
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 7885.72285927
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 7835.87335243
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 7774.56531578
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 7699.89071194
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 7610.61270858
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 7570.36180506
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 7559.06784386
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 7554.80178424
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 7552.4205278
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 7549.69176093
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 7547.36366438
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 7545.7834294
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 7544.84786632
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 7544.3427579
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 7544.11816281
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 7543.971052
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 7543.76568297
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 7543.37154771
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 7542.49771615
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 7540.40459241
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 7535.76127324
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 7531.329449
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 7528.32599146
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 7526.49237674
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 7524.7032642
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 7522.63770256
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 7520.70149297
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 7518.21276267
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 7513.97842764
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 7506.9439791
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 7501.07574719
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 7497.38634938
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 7495.21670728
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 7493.64577963
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 7492.90240955
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 7492.59366394
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 7492.40364115
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 7492.26907868
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 7492.19580787
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 7492.16564661
# center shift 1.438965e-03 within tolerance 4.019354e-06
# KMeans(algorithm='auto', copy_x=True,
#     init=array([[ 0.23867,  0.0929 ,  0.29756],
#        [ 0.57614,  0.16802,  0.37715],
#        [ 0.68046,  0.65548,  0.45814],
#        [ 0.27504,  0.3954 ,  0.15424],
#        [ 0.51388,  0.57043,  0.16779],
#        [ 0.7263 ,  0.77025,  0.16109],
#        [ 0.61188,  0.37879,  0.14739],
#        [ 0.10969,  0.23394,  0.19279],
#        [ 0.43845,  0.16228,  0.23217],
#        [ 0.26282,  0.14338,  0.12333]]),
#     max_iter=100, n_clusters=10, n_init=1, n_jobs=1,
#     precompute_distances='auto', random_state=None, tol=0.0001, verbose=1)

# %% [markdown]
# Takes around 46 iterations for the centroids to Converge

# %% [markdown]
# Run K-Means algorithm on the dataset with random centroids as the initial centroids

# %%
km_naive = KMeans(n_clusters=NUM_CLUSTERS, init='random', max_iter=100, verbose=1, n_init=1)
km_naive.fit(data)
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 10257.2370256
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 8630.91808378
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 8253.6269471
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 8104.10087852
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 8022.72296289
# start iteration
# done sorting
# end inner loop
# Iteration 5, inertia 7967.40238132
# start iteration
# done sorting
# end inner loop
# Iteration 6, inertia 7908.7181642
# start iteration
# done sorting
# end inner loop
# Iteration 7, inertia 7848.38017324
# start iteration
# done sorting
# end inner loop
# Iteration 8, inertia 7807.12915787
# start iteration
# done sorting
# end inner loop
# Iteration 9, inertia 7789.58410833
# start iteration
# done sorting
# end inner loop
# Iteration 10, inertia 7782.26327502
# start iteration
# done sorting
# end inner loop
# Iteration 11, inertia 7776.94669512
# start iteration
# done sorting
# end inner loop
# Iteration 12, inertia 7771.99610341
# start iteration
# done sorting
# end inner loop
# Iteration 13, inertia 7768.2388272
# start iteration
# done sorting
# end inner loop
# Iteration 14, inertia 7763.43666662
# start iteration
# done sorting
# end inner loop
# Iteration 15, inertia 7760.50613507
# start iteration
# done sorting
# end inner loop
# Iteration 16, inertia 7759.02551456
# start iteration
# done sorting
# end inner loop
# Iteration 17, inertia 7757.86093321
# start iteration
# done sorting
# end inner loop
# Iteration 18, inertia 7756.73894547
# start iteration
# done sorting
# end inner loop
# Iteration 19, inertia 7755.84717423
# start iteration
# done sorting
# end inner loop
# Iteration 20, inertia 7755.25732626
# start iteration
# done sorting
# end inner loop
# Iteration 21, inertia 7754.78371152
# start iteration
# done sorting
# end inner loop
# Iteration 22, inertia 7754.41002495
# start iteration
# done sorting
# end inner loop
# Iteration 23, inertia 7754.14439802
# start iteration
# done sorting
# end inner loop
# Iteration 24, inertia 7753.95597933
# start iteration
# done sorting
# end inner loop
# Iteration 25, inertia 7753.80056425
# start iteration
# done sorting
# end inner loop
# Iteration 26, inertia 7753.67441631
# start iteration
# done sorting
# end inner loop
# Iteration 27, inertia 7753.55614906
# start iteration
# done sorting
# end inner loop
# Iteration 28, inertia 7753.44566227
# start iteration
# done sorting
# end inner loop
# Iteration 29, inertia 7753.33550085
# start iteration
# done sorting
# end inner loop
# Iteration 30, inertia 7753.21777974
# start iteration
# done sorting
# end inner loop
# Iteration 31, inertia 7753.09746636
# start iteration
# done sorting
# end inner loop
# Iteration 32, inertia 7752.95432021
# start iteration
# done sorting
# end inner loop
# Iteration 33, inertia 7752.75782305
# start iteration
# done sorting
# end inner loop
# Iteration 34, inertia 7752.51615992
# start iteration
# done sorting
# end inner loop
# Iteration 35, inertia 7752.22936467
# start iteration
# done sorting
# end inner loop
# Iteration 36, inertia 7751.96089604
# start iteration
# done sorting
# end inner loop
# Iteration 37, inertia 7751.6785657
# start iteration
# done sorting
# end inner loop
# Iteration 38, inertia 7751.37224025
# start iteration
# done sorting
# end inner loop
# Iteration 39, inertia 7751.04109327
# start iteration
# done sorting
# end inner loop
# Iteration 40, inertia 7750.66221845
# start iteration
# done sorting
# end inner loop
# Iteration 41, inertia 7750.25587361
# start iteration
# done sorting
# end inner loop
# Iteration 42, inertia 7749.72202568
# start iteration
# done sorting
# end inner loop
# Iteration 43, inertia 7749.04603408
# start iteration
# done sorting
# end inner loop
# Iteration 44, inertia 7748.09012274
# start iteration
# done sorting
# end inner loop
# Iteration 45, inertia 7746.739648
# start iteration
# done sorting
# end inner loop
# Iteration 46, inertia 7745.29091799
# start iteration
# done sorting
# end inner loop
# Iteration 47, inertia 7744.10340894
# start iteration
# done sorting
# end inner loop
# Iteration 48, inertia 7743.12374805
# start iteration
# done sorting
# end inner loop
# Iteration 49, inertia 7742.45070299
# start iteration
# done sorting
# end inner loop
# Iteration 50, inertia 7741.99567428
# start iteration
# done sorting
# end inner loop
# Iteration 51, inertia 7741.60802139
# start iteration
# done sorting
# end inner loop
# Iteration 52, inertia 7741.31252992
# start iteration
# done sorting
# end inner loop
# Iteration 53, inertia 7741.07728382
# start iteration
# done sorting
# end inner loop
# Iteration 54, inertia 7740.89001646
# start iteration
# done sorting
# end inner loop
# Iteration 55, inertia 7740.72760606
# start iteration
# done sorting
# end inner loop
# Iteration 56, inertia 7740.55565375
# start iteration
# done sorting
# end inner loop
# Iteration 57, inertia 7740.35289882
# start iteration
# done sorting
# end inner loop
# Iteration 58, inertia 7740.10070371
# start iteration
# done sorting
# end inner loop
# Iteration 59, inertia 7739.80877519
# start iteration
# done sorting
# end inner loop
# Iteration 60, inertia 7739.41323153
# start iteration
# done sorting
# end inner loop
# Iteration 61, inertia 7738.88529087
# start iteration
# done sorting
# end inner loop
# Iteration 62, inertia 7738.10605288
# start iteration
# done sorting
# end inner loop
# Iteration 63, inertia 7737.12756582
# start iteration
# done sorting
# end inner loop
# Iteration 64, inertia 7735.96897816
# start iteration
# done sorting
# end inner loop
# Iteration 65, inertia 7734.40307723
# start iteration
# done sorting
# end inner loop
# Iteration 66, inertia 7731.86126788
# start iteration
# done sorting
# end inner loop
# Iteration 67, inertia 7728.03601577
# start iteration
# done sorting
# end inner loop
# Iteration 68, inertia 7723.24631305
# start iteration
# done sorting
# end inner loop
# Iteration 69, inertia 7719.36374745
# start iteration
# done sorting
# end inner loop
# Iteration 70, inertia 7716.1866864
# start iteration
# done sorting
# end inner loop
# Iteration 71, inertia 7712.93848759
# start iteration
# done sorting
# end inner loop
# Iteration 72, inertia 7708.69863919
# start iteration
# done sorting
# end inner loop
# Iteration 73, inertia 7705.07501285
# start iteration
# done sorting
# end inner loop
# Iteration 74, inertia 7703.0069696
# start iteration
# done sorting
# end inner loop
# Iteration 75, inertia 7701.73805574
# start iteration
# done sorting
# end inner loop
# Iteration 76, inertia 7701.05353195
# start iteration
# done sorting
# end inner loop
# Iteration 77, inertia 7700.60005564
# start iteration
# done sorting
# end inner loop
# Iteration 78, inertia 7700.24866034
# start iteration
# done sorting
# end inner loop
# Iteration 79, inertia 7699.90811994
# start iteration
# done sorting
# end inner loop
# Iteration 80, inertia 7699.61429436
# start iteration
# done sorting
# end inner loop
# Iteration 81, inertia 7699.35479759
# start iteration
# done sorting
# end inner loop
# Iteration 82, inertia 7699.16403655
# start iteration
# done sorting
# end inner loop
# Iteration 83, inertia 7698.97659487
# start iteration
# done sorting
# end inner loop
# Iteration 84, inertia 7698.84644517
# start iteration
# done sorting
# end inner loop
# Iteration 85, inertia 7698.74776378
# center shift 1.893563e-03 within tolerance 4.019354e-06
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=100,
#     n_clusters=10, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=1)

# %% [markdown]
# Takes 85 iterations for the centroids to Converge. <br> <br>
# Hence, the method of finding better centroids using above method has worked.
